# %%
library('yaml')
library('igraph')

# %%
data = yaml.load_file('outputs/stats/31/invertebrate/GCF_000002075.1_AplCal3.0_genomic.stats')

# %%
data$linear_paths$bins
# Out:
#   [1]    31.00   130.69   230.38   330.07   429.76   529.45   629.14   728.83
#   [9]   828.52   928.21  1027.90  1127.59  1227.28  1326.97  1426.66  1526.35
#  [17]  1626.04  1725.73  1825.42  1925.11  2024.80  2124.49  2224.18  2323.87
#  [25]  2423.56  2523.25  2622.94  2722.63  2822.32  2922.01  3021.70  3121.39
#  [33]  3221.08  3320.77  3420.46  3520.15  3619.84  3719.53  3819.22  3918.91
#  [41]  4018.60  4118.29  4217.98  4317.67  4417.36  4517.05  4616.74  4716.43
#  [49]  4816.12  4915.81  5015.50  5115.19  5214.88  5314.57  5414.26  5513.95
#  [57]  5613.64  5713.33  5813.02  5912.71  6012.40  6112.09  6211.78  6311.47
#  [65]  6411.16  6510.85  6610.54  6710.23  6809.92  6909.61  7009.30  7108.99
#  [73]  7208.68  7308.37  7408.06  7507.75  7607.44  7707.13  7806.82  7906.51
#  [81]  8006.20  8105.89  8205.58  8305.27  8404.96  8504.65  8604.34  8704.03
#  [89]  8803.72  8903.41  9003.10  9102.79  9202.48  9302.17  9401.86  9501.55
# ...

# %%
data$motifs$`4`[[1]]
# Out:
# [1] "graph G {\n0;\n1;\n2;\n3;\n1--0 ;\n2--0 ;\n3--0 ;\n}\n"
# [2] "graph G {\n0;\n1;\n2;\n3;\n2--1 ;\n3--0 ;\n3--1 ;\n}\n"
# [3] "graph G {\n0;\n1;\n2;\n3;\n1--0 ;\n2--0 ;\n3--0 ;\n3--1 ;\n}\n"
# [4] "graph G {\n0;\n1;\n2;\n3;\n2--0 ;\n2--1 ;\n3--0 ;\n3--1 ;\n}\n"
# [5] "graph G {\n0;\n1;\n2;\n3;\n2--0 ;\n2--1 ;\n3--0 ;\n3--1 ;\n3--2 ;\n}\n"

# %%
for (size in names(data$motifs)) {
    motifs <- data$motifs[[size]]
    graphs <- motifs[[1]]
    stats <- motifs[[2]]
    
}
